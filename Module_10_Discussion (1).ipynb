# %% [markdown]
# ### Module 10 Discussion (Untidy Data Sets)

# %%
from urllib.request import urlopen
import json 
from pandas.io.json import json_normalize
import pandas as pd
import requests

# making sure the row displays all the contents
pd.set_option('display.max_colwidth', None)

snap_data = json.loads(requests.get('https://raw.githubusercontent.com/mbjamil92/DAV-5400/main/location_history.json').text)

snap_df = pd.DataFrame.from_dict(df, orient='index').T

# %%
snap_df
# Out:
#                                                Frequent Locations  \
# 0     {'City': 'east setauket', 'Country': 'usa', 'Region': 'ny'}
# 1     {'City': 'east setauket', 'Country': 'usa', 'Region': 'ny'}
# 2                                                            None
# 3                                                            None
# 4                                                            None
# ...                                                           ...
# 2168                                                         None
# 2169                                                         None
# 2170                                                         None
# 2171                                                         None
# 2172                                                         None
#
#                                                   Latest Location Home & Work  \
# 0     {'City': 'east setauket', 'Country': 'usa', 'Region': 'ny'}        Home
# ...
