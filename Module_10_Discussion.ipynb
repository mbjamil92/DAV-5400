# %% [markdown]
# ### Module 10 Discussion (Untidy Data Sets)

# %%
from urllib.request import urlopen
import json 
from pandas.io.json import json_normalize
import pandas as pd
import requests

snap_data = json.loads(requests.get('https://raw.githubusercontent.com/mbjamil92/DAV-5400/main/location_history.json').text)

snap_df = pd.DataFrame.from_dict(df, orient='index').T

# %%
snap_df
# Out:
#                                      Frequent Locations  \
# 0     {'City': 'east setauket', 'Country': 'usa', 'R...
# 1     {'City': 'east setauket', 'Country': 'usa', 'R...
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2168                                               None
# 2169                                               None
# 2170                                               None
# 2171                                               None
# 2172                                               None
#
#                                         Latest Location Home & Work  \
# 0     {'City': 'east setauket', 'Country': 'usa', 'R...        Home
# 1                                                  None        Work
# 2                                                  None        None
# 3                                                  None        None
# 4                                                  None        None
# ...                                                 ...         ...
# 2168                                               None        None
# 2169                                               None        None
# 2170                                               None        None
# 2171                                               None        None
# 2172                                               None        None
#
#                                     Daily Top Locations  \
# 0     [{'Date: 2021-03-20 UTC': 'lat 40.907 ± 73.37 ...
# 1     [{'Date: 2021-03-22 UTC': 'lat 40.859 ± 36.71 ...
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2168                                               None
# 2169                                               None
# 2170                                               None
# 2171                                               None
# 2172                                               None
#
#                        Top Locations Per Six-Day Period  \
# 0     [{'Date: 2021-02-26 UTC': 'lat 40.908 ± 73.37 ...
# 1     [{'Date: 2021-03-04 UTC': 'lat 40.908 ± 73.37 ...
# 2     [{'Date: 2021-03-10 UTC': 'lat 40.879 ± 73.41 ...
# 3     [{'Date: 2021-03-16 UTC': 'lat 40.908 ± 73.37 ...
# 4     [{'Date: 2021-03-22 UTC': 'lat 40.859 ± 18.36 ...
# ...                                                 ...
# 2168                                               None
# 2169                                               None
# 2170                                               None
# 2171                                               None
# 2172                                               None
#
#                                        Location History  \
# 0     {'Time': '2020/09/26 01:18:36 UTC', 'Latitude,...
# 1     {'Time': '2020/09/26 01:18:40 UTC', 'Latitude,...
# 2     {'Time': '2020/09/26 01:18:42 UTC', 'Latitude,...
# 3     {'Time': '2020/09/26 01:18:43 UTC', 'Latitude,...
# 4     {'Time': '2020/09/26 01:18:57 UTC', 'Latitude,...
# ...                                                 ...
# 2168  {'Time': '2021/03/23 02:55:34 UTC', 'Latitude,...
# 2169  {'Time': '2021/03/23 02:55:34 UTC', 'Latitude,...
# 2170  {'Time': '2021/03/23 02:55:37 UTC', 'Latitude,...
# 2171  {'Time': '2021/03/23 02:55:51 UTC', 'Latitude,...
# 2172  {'Time': '2021/03/23 02:55:51 UTC', 'Latitude,...
#
#       Businesses and public places you may have visited  \
# 0     {'Date': '2020-11-12', 'Name': 'Checkers & Ral...
# 1     {'Date': '2020-08-13', 'Name': 'Panera Bread (...
# 2            {'Date': '2021-03-15', 'Name': 'Best Buy'}
# 3           {'Date': '2020-11-29', 'Name': 'PINK (US)'}
# 4             {'Date': '2020-08-30', 'Name': 'Walmart'}
# ...                                                 ...
# 2168                                               None
# 2169                                               None
# 2170                                               None
# 2171                                               None
# 2172                                               None
#
#        Areas you may have visited in the last two years
# 0     {'Time': '2021/01/15 03:26:29 UTC', 'City': 'i...
# 1     {'Time': '2020/03/05 20:45:35 UTC', 'City': 'p...
# 2     {'Time': '2020/08/30 20:15:27 UTC', 'City': 's...
# 3     {'Time': '2020/09/20 19:39:27 UTC', 'City': 's...
# 4     {'Time': '2019/06/16 12:48:52 UTC', 'City': 'k...
# ...                                                 ...
# 2168                                               None
# 2169                                               None
# 2170                                               None
# 2171                                               None
# 2172                                               None
#
# [2173 rows x 8 columns]
